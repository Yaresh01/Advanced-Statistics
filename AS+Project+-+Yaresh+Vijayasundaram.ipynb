# %%
import numpy as np
import pandas as pd
from scipy.stats import f
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
from scipy.stats import ttest_1samp, ttest_ind
from statsmodels.stats.power import ttest_power

# %%
from IPython.display import Image
Image(filename='/Users/yareshvijayasundaram/Desktop/Screenshot 2022-11-15 at 14.51.11.png',width=500,height=500)

# %% [markdown]
# # Problem 1
#
# A physiotherapist with a male football team is interested in studying the relationship between foot injuries and the positions at which the players play from the data collected
#
# 1.1 What is the probability that a randomly chosen player would suffer an injury?
#
# 1.2 What is the probability that a player is a forward or a winger?
#
# 1.3 What is the probability that a randomly chosen player plays in a striker position and has a foot injury?
#
# 1.4 What is the probability that a randomly chosen injured player is a striker?
#
# 1.5 What is the probability that a randomly chosen injured player is either a forward or an attacking midfielder?

# %%
145/235
# Out:
# 0.6170212765957447

# %%
(94+29)/235
# Out:
# 0.5234042553191489

# %%
45/235
# Out:
# 0.19148936170212766

# %%
45/145
# Out:
# 0.3103448275862069

# %%
(56+24)/145
# Out:
# 0.5517241379310345

# %% [markdown]
# # Problem 2
#
# An independent research organization is trying to estimate the probability that an accident at a nuclear power plant will result in radiation leakage. The types of accidents possible at the plant are, fire hazards, mechanical failure, or human error. The research organization also knows that two or more types of accidents cannot occur simultaneously.
#
# According to the studies carried out by the organization, the probability of a radiation leak in case of a fire is 20%, the probability of a radiation leak in case of a mechanical 50%, and the probability of a radiation leak in case of a human error is 10%. The studies also showed the following;
#
# The probability of a radiation leak occurring simultaneously with a fire is 0.1%.
# The probability of a radiation leak occurring simultaneously with a mechanical failure is 0.15%.
# The probability of a radiation leak occurring simultaneously with a human error is 0.12%.
# On the basis of the information available, answer the questions below:
#
# 2.1 What are the probabilities of a fire, a mechanical failure, and a human error respectively?
#
# 2.2 What is the probability of a radiation leak?
#
# 2.3 Suppose there has been a radiation leak in the reactor for which the definite cause is not known. What is the probability that it has been caused by:
#
# A Fire.
# A Mechanical Failure.
# A Human Error.

# %% [markdown]
# P(R|F)=0.2
#
# P(R|M)=0.5
#
# P(R|H)=0.1
#
# P(R n F)=0.001
#
# P(R n M)=0.0015
#
# P(R n H)=0.0012

# %%
0.001/0.2
# Out:
# 0.005

# %%
0.0015/0.5
# Out:
# 0.003

# %%
0.0012/0.1
# Out:
# 0.011999999999999999

# %%
0.001+0.0015+0.0012
# Out:
# 0.0037

# %%
0.001/0.0037
# Out:
# 0.2702702702702703

# %%
0.0015/0.0037
# Out:
# 0.4054054054054054

# %%
0.0012/0.0037
# Out:
# 0.3243243243243243

# %% [markdown]
# # Problem 3:
#
# The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information; (Provide an appropriate visual representation of your answers, without which marks will be deducted)
#
#
#
# 3.1 What proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm?
#
# 3.2 What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?
#
# 3.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?
#
# 3.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
from scipy.stats import norm

mu=5
sigma=1.5

prob_less=norm.cdf(3.17,mu,sigma)

print('The proabality of the gunny bags have a breaking strength less than 3.17kg per sq cm is', round(prob_less,4))
# Out:
# The proabality of the gunny bags have a breaking strength less than 3.17kg per sq cm is 0.1112

# %%
prob_less*100
# Out:
# 11.123243744783457

# %%
density= pd.DataFrame()
density['x']=np.linspace(0,10,100)
density['pdf']=norm.pdf(density['x'],5,1.5)

plt.plot (density["x"], density["pdf"])
plt.axvline(x=3.17, c="b")
x1 = np.linspace(0,3.17, 50)
plt.fill_between(x1, norm.pdf(x1, 5, 1.5), color="b") 
plt.xlabel ("Breaking Strength") 
plt.ylabel("Probability") 
plt.title( "Normal Distribution") 
plt.show()

# %%
mu=5
sigma=1.5

prob_atleast=1-norm.cdf(3.6,mu,sigma)

print('The propotion of the gunny bags have a breaking strength at least 3.6kg per sq cm is',round(prob_atleast,4))
# Out:
# The propotion of the gunny bags have a breaking strength at least 3.6kg per sq cm is 0.8247

# %%
prob_atleast*100
# Out:
# 82.46760551477705

# %%
plt.plot (density["x"], density["pdf"])
plt.axvline(x=3.6, c="b")
x1 = np.linspace(3.6,10,50)
plt.fill_between(x1, norm.pdf(x1, 5, 1.5), color="b") 
plt.xlabel ("Breaking Strength") 
plt.ylabel("Probability") 
plt.title( "Normal Distribution") 
plt.show()

# %%
mu=5
sigma=1.5

prop_btw=stats.norm.cdf(5.5,loc=mu,scale=sigma)-stats.norm.cdf(5,loc=mu,scale=sigma)

print('The proportion of the gunny bags have a breaking strenth between 5 and 5.5kg per sq cm', round(prop_btw,4))
# Out:
# The proportion of the gunny bags have a breaking strenth between 5 and 5.5kg per sq cm 0.1306

# %%
prop_btw*100
# Out:
# 13.055865981823633

# %%
plt.plot (density["x"], density["pdf"])
plt.axvline(x=5, c="b")
plt.axvline(x=5.5,c="b")
x1 = np.linspace(5,5.5,50)
plt.fill_between(x1, norm.pdf(x1, 5, 1.5), color="blue") 
plt.xlabel ("Breaking Strength") 
plt.ylabel("Probability") 
plt.title( "Normal Distribution") 
plt.show()

# %%
mu=5
sigma=1.5

pdf=1+stats.norm.cdf(3,loc=mu,scale=sigma)-stats.norm.cdf(7.5,loc=mu,scale=sigma)

print('The Proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm', round(pdf,4))
# Out:
# The Proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm 0.139

# %%
pdf*100
# Out:
# 13.900157199868257

# %%
plt.plot(density['x'],density['pdf'])
plt.axvline(x=3,c='g')
plt.axvline(x=7.5,c='g')
x1=np.linspace(0,3,50)
x2=np.linspace(7.5,10,50)
plt.fill_between(x1,norm.pdf(x1,5,1.5),color='g')
plt.fill_between(x2,norm.pdf(x2,5,1.5),color='g')
plt.xlabel('Breaking strength')
plt.ylabel('Probablity')
plt.title('Normal distrubtion')
plt.show()

# %% [markdown]
# # 4. Grades of the final examination in a training course are found to be normally distributed, with a mean of 77 and a standard deviation of 8.5. Based on the given information answer the questions below.
#
#
#
# 4.1 What is the probability that a randomly chosen student gets a grade below 85 on this exam?
#
# 4.2 What is the probability that a randomly selected student scores between 65 and 87?
#
# 4.3 What should be the passing cut-off so that 75% of the students clear the exam?

# %%
mu=77
sigma=8.5

# %%
z=(85-77)/8.5
z
# Out:
# 0.9411764705882353

# %%
stats.norm.cdf(85,77,8.5)
# Out:
# 0.8266927837484748

# %%
den1=pd.DataFrame()
den1['x']=np.linspace(50,100,400)
den1['pdf']=norm.pdf(den1['x'],77,8.5)

# %%
plt.plot(den1['x'],den1['pdf'])
plt.axvline(x=85,c='g')
x1=np.linspace(50,85,50)
plt.fill_between(x1,norm.pdf(x1,77,8.5),color='y')
plt.xlabel('Grades')
plt.ylabel('Probability')
plt.title('Normal Distrubtion')
plt.show();

# %%
stats.norm.cdf(87,77,8.5)-stats.norm.cdf(65,77,8.5)
# Out:
# 0.8012869336779058

# %%
plt.plot(den1['x'],den1['pdf'])
plt.axvline(x=65,c='g')
plt.axvline(x=87,c='g')
x1=np.linspace(65,87,50)
plt.fill_between(x1,norm.pdf(x1,77,8.5),color='g')
plt.xlabel('Grades')
plt.ylabel('Probability')
plt.title('Normal Distrubtion')
plt.show();

# %%
stats.norm.ppf(0.25,77,8.5)
# Out:
# 71.2668371233333

# %%
passing_cut_off=stats.norm.ppf(0.25,loc=77,scale=8.5)
passing_cut_off
# Out:
# 71.2668371233333

# %%
plt.plot(den1['x'],den1['pdf'])
plt.axvline(passing_cut_off,c='r')
plt.xlabel('Grades')
plt.ylabel('Probability')
plt.title('Normal Distrubtion')
plt.show();

# %% [markdown]
# # Problem 5:
#
#
#
# Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);
#
#
#
# 5.1 Earlier experience of Zingaro with this particular client is favorable as the stone surface was found to be of adequate hardness. However, Zingaro has reason to believe now that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?
#
# 5.2 Is the mean hardness of the polished and unpolished stones the same?

# %% [markdown]
# Null hypothesis: Unpolished stone is good for printing:
#
# Alternative Hypothesis: Unpolished stone is not good for printing

# %%
df1=pd.read_csv('/Users/yareshvijayasundaram/Downloads/download-9.csv')

# %%
df1.head()
# Out:
#    Unpolished   Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227

# %% [markdown]
# Null Hypothesis: The mean hardness of unpolished stone is at least equal to 150.
#
# Alternative Hypothesis: The mean hardness of unpolished stone is less than 150.

# %%
df10=df1.rename(columns={df1.columns[0]: 'UNPOLISHED'})
df10
# Out:
#     UNPOLISHED  Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227
# ..         ...                   ...
# 70  123.067611            142.293544
# 71  171.822218            140.124092
# 72   88.135994            141.393091
# 73  145.150397            131.370530
# 74  170.854823            144.502647
#
# [75 rows x 2 columns]

# %%
print("The sample size for this problem is",len(df10))
# Out:
# The sample size for this problem is 75

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UNPOLISHED            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %%
t_statistic, p_value = ttest_1samp(df10['UNPOLISHED'], 150)
print('One sample t test \nt statistic: {0} p value: {1} '.format(t_statistic, p_value))
# Out:
# One sample t test
# t statistic: -4.164629601426758 p value: 8.342573994839285e-05

# %%
p_value/2
# Out:
# 4.1712869974196425e-05

# %%
alpha_value = 0.05 # Level of significance
p_value=4.17128700e-05
print('Level of significance: %.2f' %alpha_value)
if p_value < alpha_value: 
    print('We have evidence to reject the null hypothesis since p value < Level of significance')
else:
    print('We have no evidence to reject the null hypothesis since p value > Level of significance') 

print ("Our one-sample t-test p-value=", p_value)
# Out:
# Level of significance: 0.05
# We have evidence to reject the null hypothesis since p value < Level of significance
# Our one-sample t-test p-value= 4.171287e-05

# %%
df1.describe()
# Out:
#        Unpolished   Treated and Polished
# count    75.000000             75.000000
# mean    134.110527            147.788117
# std      33.041804             15.587355
# min      48.406838            107.524167
# 25%     115.329753            138.268300
# 50%     135.597121            145.721322
# 75%     158.215098            157.373318
# max     200.161313            192.272856

# %% [markdown]
# Null Hypothesis: The mean hardness of polished and unpolished stones are the same.
#
# Alternative Hypothesis: The mean hardness of polished and unpolished stones are not the

# %%
df10=df1.rename(columns={df1.columns[0]: 'UNPOLISHED'})
df10
# Out:
#     UNPOLISHED  Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227
# ..         ...                   ...
# 70  123.067611            142.293544
# 71  171.822218            140.124092
# 72   88.135994            141.393091
# 73  145.150397            131.370530
# 74  170.854823            144.502647
#
# [75 rows x 2 columns]

# %%
t_statistic, p_value  = ttest_ind(df10['UNPOLISHED'],df10['Treated and Polished'])
print('two sample t test \nt statistic: {0} p value: {1} '.format(t_statistic, p_value))
# Out:
# two sample t test
# t statistic: -3.242232050141406 p value: 0.001465515019462831

# %%
alpha_value = 0.05 # Level of significance
p_value
print('Level of significance: %.2f' %alpha_value)
if p_value < alpha_value: 
    print('We have evidence to reject the null hypothesis since p value < Level of significance')
else:
    print('We have no evidence to reject the null hypothesis since p value > Level of significance') 

print ("Our one-sample t-test p-value=", p_value)
# Out:
# Level of significance: 0.05
# We have evidence to reject the null hypothesis since p value < Level of significance
# Our one-sample t-test p-value= 0.001465515019462831

# %% [markdown]
# # Problem 6:
#
#
#
# Aquarius health club, one of the largest and most popular cross-fit gyms in the country has been advertising a rigorous program for body conditioning. The program is considered successful if the candidate is able to do more than 5 push-ups, as compared to when he/she enrolled in the program. Using the sample data provided can you conclude whether the program is successful? (Consider the level of Significance as 5%)
#
# Note that this is a problem of the paired-t-test. Since the claim is that the training will make a difference of more than 5, the null and alternative hypotheses must be formed accordingly.

# %%
df2=pd.read_csv('/Users/yareshvijayasundaram/Downloads/Aquarius_gym.csv')

# %%
df2.head()
# Out:
#    Sr no.  Before  After
# 0       1      39     44
# 1       2      25     25
# 2       3      39     39
# 3       4       6     13
# 4       5      40     44

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sr no.  100 non-null    int64
#  1   Before  100 non-null    int64
#  2   After   100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB

# %%
df2.describe()
# Out:
#            Sr no.      Before       After
# count  100.000000  100.000000  100.000000
# mean    50.500000   26.940000   32.490000
# std     29.011492    8.806357    8.779562
# min      1.000000    3.000000   10.000000
# 25%     25.750000   21.750000   26.000000
# 50%     50.500000   28.000000   34.000000
# 75%     75.250000   32.250000   39.000000
# max    100.000000   47.000000   51.000000

# %%
sns.boxplot(data=df2,x='Before')
# Out:
# <AxesSubplot:xlabel='Before'>

# %%
sns.boxplot(data=df2,x='After')
# Out:
# <AxesSubplot:xlabel='After'>

# %% [markdown]
# Null Hypothesis – The mean difference of push ups is equal to 5
#
# Alternative Hypothesis – The mean difference of push ups is greater than 5

# %%
df2['Difference']=df2['After']-df2['Before']

# %%
mean_difference=df2['Difference'].mean()
mean_difference
# Out:
# 5.55

# %%
Difference=df2['Difference'].std()
Difference
# Out:
# 2.8722813232690143

# %%
np.sqrt(100)
# Out:
# 10.0

# %%
tstat=(mean_difference-5)/(Difference/10)
tstat
# Out:
# 1.9148542155126758

# %%
P_value=1-stats.t.cdf(tstat,99)
P_value
# Out:
# 0.029198872141011245

# %%
alpha_value = 0.05 # Level of significance
P_value
print('Level of significance: %.2f' %alpha_value)
if p_value < alpha_value: 
    print('We have evidence to reject the null hypothesis since p value < Level of significance')
else:
    print('We have no evidence to reject the null hypothesis since p value > Level of significance') 

print ("t-test P-value=", P_value)
# Out:
# Level of significance: 0.05
# We have evidence to reject the null hypothesis since p value < Level of significance
# t-test P-value= 0.029198872141011245

# %% [markdown]
# # Question 7:
#
# Dental implant data: The hardness of metal implant in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as on the dentists who may favour one method above another and may work better in his/her favourite method. The response is the variable of interest.

# %%
df=pd.read_excel('/Users/yareshvijayasundaram/Downloads/Dental Hardness data.xlsx')

# %%
from statsmodels.formula.api import ols      # For n-way ANOVA
from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA

# %%
df.head()
# Out:
#    Dentist  Method  Alloy    Temp  Response  Unnamed: 5  Unnamed: 6  \
# 0      1.0     1.0    1.0  1500.0     813.0         NaN         NaN
# 1      1.0     1.0    1.0  1600.0     792.0         NaN         NaN
# 2      1.0     1.0    1.0  1700.0     792.0         NaN         NaN
# 3      1.0     1.0    2.0  1500.0     907.0         NaN         NaN
# 4      1.0     1.0    2.0  1600.0     792.0         NaN         NaN
#
#                               Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0  Anova: Two-Factor Without Replication        NaN        NaN         NaN
# 1                                    NaN        NaN        NaN         NaN
# 2                                SUMMARY      Count        Sum     Average
# 3                                      1          4       2315      578.75
# 4                                      1          4       2394       598.5
#
#      Unnamed: 11 Unnamed: 12 Unnamed: 13
# 0            NaN         NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dentist      90 non-null     float64
#  1   Method       90 non-null     float64
#  2   Alloy        90 non-null     float64
#  3   Temp         90 non-null     float64
#  4   Response     90 non-null     float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   102 non-null    object
#  8   Unnamed: 8   100 non-null    object
#  9   Unnamed: 9   100 non-null    object
#  10  Unnamed: 10  99 non-null     object
#  11  Unnamed: 11  98 non-null     object
#  12  Unnamed: 12  3 non-null      object
#  13  Unnamed: 13  3 non-null      object
# dtypes: float64(7), object(7)
# memory usage: 11.8+ KB

# %%
df.describe(include='all')
# Out:
#           Dentist     Method      Alloy         Temp     Response  Unnamed: 5  \
# count   90.000000  90.000000  90.000000    90.000000    90.000000         0.0
# unique        NaN        NaN        NaN          NaN          NaN         NaN
# top           NaN        NaN        NaN          NaN          NaN         NaN
# freq          NaN        NaN        NaN          NaN          NaN         NaN
# mean     3.000000   2.000000   1.500000  1600.000000   741.777778         NaN
# std      1.422136   0.821071   0.502801    82.107083   145.767845         NaN
# min      1.000000   1.000000   1.000000  1500.000000   289.000000         NaN
# 25%      2.000000   1.000000   1.000000  1500.000000   698.000000         NaN
# 50%      3.000000   2.000000   1.500000  1600.000000   767.000000         NaN
# 75%      4.000000   3.000000   2.000000  1700.000000   824.000000         NaN
# max      5.000000   3.000000   2.000000  1700.000000  1115.000000         NaN
#
# ...

# %%
df.Dentist= pd.Categorical(df.Dentist)
df.Method=pd.Categorical(df.Method)
df.Alloy=pd.Categorical(df.Alloy)

# %% [markdown]
# 7.1 Test whether there is any difference among the dentists on the implant hardness. State the null and alternative hypotheses. Note that both types of alloys cannot be considered together. You must state the null and alternative hypotheses separately for the two types of alloys.?

# %%
alloy1=df[df['Alloy']==1.0]
alloy2=df[df['Alloy']==2.0]

# %% [markdown]
# H0: Mean dental hardness among all the denist is same for alloy 1
#
# Ha: Mean dental hardness among all the denist is not the same for alloy 1

# %%
formula = 'Response  ~ C(Dentist)'
model = ols(formula, alloy1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %% [markdown]
# H0: Mean dental hardness among all the denist is same for alloy 2
#
# Ha: Mean dental hardness among all the denist is not the same for alloy 2

# %%
formula = 'Response  ~ C(Dentist)'
model = ols(formula, alloy2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %% [markdown]
# 7.2 Before the hypotheses may be tested, state the required assumptions. Are the assumptions fulfilled? Comment separately on both alloy types.?

# %% [markdown]
# Assumptions:
#
# The data is drwan from a normally distrubtion.
#
# The variance are equal.

# %%
alloy1=df[df['Alloy']==1.0]['Response']
alloy2=df[df['Alloy']==2.0]['Response']

# %%
print(stats.shapiro([alloy1]))
print(stats.shapiro([alloy2]))
# Out:
# ShapiroResult(statistic=0.8304629921913147, pvalue=1.1945070582441986e-05)
# ShapiroResult(statistic=0.8877691626548767, pvalue=0.00040292771882377565)

# %%
print(stats.anderson(alloy2,dist='norm'))
# Out:
# AndersonResult(statistic=1.8931311726356412, critical_values=array([0.535, 0.609, 0.731, 0.853, 1.014]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
#alpha = 0.05
print(stats.levene(alloy1,alloy2))
# Out:
# LeveneResult(statistic=1.4194717470917784, pvalue=0.23669380462584474)

# %% [markdown]
# For alloy 1 the data is normally distrubted.
# For alloy 2 the data is not normally distrubted.

# %% [markdown]
# 7.3 Irrespective of your conclusion in 7.2, we will continue with the testing procedure. What do you conclude regarding whether implant hardness depends on dentists? Clearly state your conclusion. If the null hypothesis is rejected, is it possible to identify which pairs of dentists differ?

# %% [markdown]
# H0: The mean implant hardness is same with all five denists
#
# H1: The mean implant hardness is not the same with atleast one denist.

# %%
formula = 'Response  ~ C(Dentist)'
model = ols(formula, df).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  1.577946e+05  39448.638889  1.934537  0.112066
# Residual    85.0  1.733301e+06  20391.776471       NaN       NaN

# %% [markdown]
# 7.4 Now test whether there is any difference among the methods on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which pairs of methods differ?

# %% [markdown]
# H0:The mean dental hardness implant is same across all methods for alloy1
#
# Ha:The mean hardness of dental implant is different for atleast one method for alloy 1

# %%
alloy1=df[df['Alloy']==1.0]
alloy2=df[df['Alloy']==2.0]

# %%
formula = 'Response  ~ C(Method)'
model = ols(formula, alloy1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %% [markdown]
# H0:The mean dental hardness implant is same across all methods for alloy2
#
# Ha:The mean hardness of dental implant is different for atleast one method for alloy2

# %%
formula = 'Response  ~ C(Method)'
model = ols(formula, alloy2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#              df    sum_sq        mean_sq        F    PR(>F)
# C(Method)   2.0  499640.4  249820.200000  16.4108  0.000005
# Residual   42.0  639362.4   15222.914286      NaN       NaN

# %% [markdown]
# 7.5 Now test whether there is any difference among the temperature levels on the hardness of dental implant, separately for the two types of alloys. What are your conclusions? If the null hypothesis is rejected, is it possible to identify which levels of temperatures differ?

# %% [markdown]
# H0:The mean hardness of dental implant is the same for diffent level of temp for alloy 1
#
# Ha:The mean hardness of dental implant is different for atleast one level of temperature for alloy 1

# %%
df.Alloy=pd.Categorical(df.Temp)

# %%
formula = 'Response  ~ C(Temp)'
model = ols(formula, alloy1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#             df         sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0   10154.444444   5077.222222  0.335224  0.717074
# Residual  42.0  636122.800000  15145.780952       NaN       NaN

# %% [markdown]
# H0:The mean hardness of dental implant is the same for diffent level of temp for alloy 2
#
# Ha:The mean hardness of dental implant is different for atleast one level of temperature for alloy 2

# %%
formula = 'Response  ~ C(Temp)'
model = ols(formula, alloy2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#             df        sum_sq       mean_sq         F    PR(>F)
# C(Temp)    2.0  9.374893e+04  46874.466667  1.883492  0.164678
# Residual  42.0  1.045254e+06  24886.996825       NaN       NaN

# %% [markdown]
# 7.6 Consider the interaction effect of dentist and method and comment on the interaction plot, separately for the two types of alloys?

# %%
formula = 'Response ~ C(Dentist) + C(Method)'
model = ols(formula, alloy1).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=alloy1, hue='Method',ci=None);
plt.title('Interaction effect of alloy1')
# Out:
# /Users/yareshvijayasundaram/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# /Users/yareshvijayasundaram/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Interaction effect of alloy1')

# %%
formula = 'Response ~ C(Dentist) + C(Method)'
model = ols(formula, alloy2).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=alloy2, hue='Method',ci=None);
plt.title('Interaction effect of alloy2')
# Out:
# /Users/yareshvijayasundaram/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# /Users/yareshvijayasundaram/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:253: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped_vals = vals.groupby(grouper)
# Text(0.5, 1.0, 'Interaction effect of alloy2')

# %% [markdown]
# 7.7 Now consider the effect of both factors, dentist, and method, separately on each alloy. What do you conclude? Is it possible to identify which dentists are different, which methods are different, and which interaction levels are different?

# %%
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, alloy1).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist):C(Method)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %%
formula = 'Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model = ols(formula, alloy2).fit()
aov_table = anova_lm(model)
(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist):C(Method)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN
